# %%
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup
import csv
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data Scraping

# %%
def get_rating(link):
    page = urlopen(link)
    soup = BeautifulSoup(page, 'html.parser')
    score = soup.find("em", class_='cnt')
    return score.contents[0]

# %%
def get_chapter(link):
    page = urlopen(link)
    soup = BeautifulSoup(page, 'html.parser')
    chapter = soup.find("span", class_='tx')
    chapter = chapter.contents[0]
    return int(chapter.replace("#",''))

# %%
quote_page = 'https://www.webtoons.com/en/dailySchedule'

# query the website and return the html to the variable ‘page’
page = urlopen(quote_page)
soup = BeautifulSoup(page, 'html.parser')

# create csv
webtoon_data = csv.writer(open('webtoons_data.csv', 'w'))
webtoon_data.writerow(['Name', 'Heart', 'Score', 'Genre', 'Status', "Episode"])


everyday = np.array(["MONDAY","TUESDAY","WEDNESDAY","THURSDAY","FRIDAY","SATURDAY","SUNDAY","COMPLETED"])
for i in range(len(everyday)):
    if everyday[i] == "COMPLETED":
        update_find = "daily_lst comp"
    else: 
        update_find = "daily_section _list_" + everyday[i]
    d_day = soup.find(class_= update_find)
    name = d_day.find_all('p', class_ = 'subj')
    likes = d_day.find_all('em')
    score = d_day.find_all()
    genre = d_day.find_all('p', class_ = 'genre')
    webtoon_link = []
    for link in d_day.find_all('a'):
        if link.get('href') == "#":
            continue
        else:
            webtoon_link.append(link.get('href'))
    for n,l,g,s in zip(name, likes, genre, range(len(webtoon_link))):
        N = n.contents[0]
        L = l.contents[0]
        G = g.contents[0]
        scores = get_rating(webtoon_link[s])
        chapters = get_chapter(webtoon_link[s])
        webtoon_data.writerow([N,L,scores,G,everyday[i],chapters])

# %% [markdown]
# ## Using pandas

# %%
df = pd.read_csv('webtoons_data.csv')

# Delete repeated webtoons since some update more than once a week
df.drop_duplicates(subset = "Name", inplace = True)

# %%
df
# Out:
#                                         Name    Heart  Score          Genre  \
# 0                                      Edith     1.5M   9.77        Romance
# 1                                    SubZero     2.3M   9.82        Romance
# 2                       Cursed Princess Club     1.2M   9.74         Comedy
# 3                                 Sweet Home     5.8M   9.84       Thriller
# 4                    My Giant Nerd Boyfriend    20.7M   9.73  Slice of life
# 5                                 Ghost Wife     3.9M   9.67        Romance
# 6                               Tower of God    13.2M   9.83        Fantasy
# 7                                  Code Adam  154,586   9.83         Action
# 8    Love Advice from the Great Duke of Hell     3.5M   9.78         Comedy
# 9                           The Four of Them  857,800   9.60          Drama
# 10                            Room of Swords     1.8M   9.78         Sci-fi
# 11                                    Big Jo     3.3M   9.54          Drama
# 12                           Matchmaker Hero  471,971   9.69         Sci-fi
# 13                         Safely Endangered     9.6M   9.54         Comedy
# 14                                DON'T HATE  678,772   9.43         Comedy
# 15                               Heir's Game  824,481   9.65          Drama
# 16                              As Per Usual     5.4M   9.39         Comedy
# 17                              Wind Breaker     2.7M   9.84         Action
# 18                           dustinteractive     4.6M   9.37         Comedy
# 19                              Aerial Magic       1M   9.69          Drama
# 20                           A Budgie's Life     5.3M   9.78  Slice of life
# 21                                      Plum  127,278   9.55         Sports
# 22                       Cat Loaf Adventures     1.3M   9.56  Slice of life
# 23                                 Messenger  376,973   9.18        Fantasy
# 24                               Lunarbaboon     2.8M   9.65  Slice of life
# 25                                    Kubera     1.7M   9.71        Fantasy
# 26                                   EMPYREA     1.2M   9.79        Fantasy
# 27                                      LUFF     2.1M   9.56        Romance
# 28                         My Deepest Secret  827,061   9.70          Drama
# 29                     Boyfriend of the Dead    13.1M   9.78         Comedy
# ..                                       ...      ...    ...            ...
# 326                                Cyberbunk   94,628   8.56         Sci-fi
# 327                             The Red Book  166,401   8.79       Thriller
# 328                         The Purple Heart   34,100   9.09      Superhero
# 329                                 UndeadEd  632,985   9.68         Comedy
# 330                 The Gentleman’s Armchair  245,413   8.90         Comedy
# 331                   All That We Hope to Be  125,814   9.46  Slice of life
# 332                                MOONBEARD  352,959   9.26         Comedy
# 333                              How to Love  491,044   9.49  Slice of life
# 334                               Trash Bird  920,780   9.53         Comedy
# 335                             Power Ballad   79,541   9.08          Drama
# 336                            Library Ghost  195,405   8.77  Slice of life
# 337                             Late Bloomer  517,512   9.31        Romance
# 338                                  War Cry   30,343   7.18      Superhero
# 339                                Pigminted  211,834   8.76  Slice of life
# 340                                    Elena  109,992   9.50       Thriller
# 341                                  Bastard       4M   9.88       Thriller
# 342                              Up and Out   487,221   8.89  Slice of life
# 343                                  SAVE ME       3M   9.88          Drama
# 344                    National Dog Day 2016  153,915   9.55  Slice of life
# 345                  Life Outside the Circle  692,583   9.28        Romance
# 346                          Cherry Blossoms   85,695   9.20        Romance
# 347                     Illustrated Internet  375,558   8.98         Comedy
# 348                               Adamsville  135,900   9.30       Thriller
# 349                 The Steam Dragon Express     2.4M   9.65        Fantasy
# 350                            City of Walls   14,042   7.44         Action
# 351                           Your Adventure   71,522   9.08         Comedy
# 352                                Dragnarok  348,155   9.49        Fantasy
# 353             LESSA 2 - The Crimson Knight  559,904   9.78        Fantasy
# 354                Fantasy Sketch - The Game   74,412   8.85        Fantasy
# 355                        Melvina's Therapy       1M   9.69         Horror
#
#         Status  Episode
# 0       MONDAY       25
# 1       MONDAY       28
# 2       MONDAY       25
# 3       MONDAY       82
# 4       MONDAY      327
# 5       MONDAY       78
# 6       MONDAY      435
# 7       MONDAY        6
# 8       MONDAY       60
# 9       MONDAY       27
# 10      MONDAY       75
# 11      MONDAY      119
# 12      MONDAY       15
# 13      MONDAY      486
# 14      MONDAY       35
# 15      MONDAY       45
# 16      MONDAY      359
# 17      MONDAY      238
# 18      MONDAY      405
# 19      MONDAY       49
# 20      MONDAY      348
# 21      MONDAY       16
# 22      MONDAY      128
# 23      MONDAY       53
# 24      MONDAY      555
# 25      MONDAY      400
# 26      MONDAY       27
# 27     TUESDAY       30
# 28     TUESDAY       15
# 29     TUESDAY      200
# ..         ...      ...
# 326  COMPLETED      194
# 327  COMPLETED       26
# 328  COMPLETED       26
# 329  COMPLETED      120
# 330  COMPLETED      142
# 331  COMPLETED      176
# 332  COMPLETED      147
# 333  COMPLETED      100
# 334  COMPLETED      174
# 335  COMPLETED       26
# 336  COMPLETED       75
# 337  COMPLETED       31
# 338  COMPLETED       26
# 339  COMPLETED      208
# 340  COMPLETED       26
# 341  COMPLETED       94
# 342  COMPLETED      129
# 343  COMPLETED       16
# 344  COMPLETED       32
# 345  COMPLETED       47
# 346  COMPLETED        7
# 347  COMPLETED       50
# 348  COMPLETED       85
# 349  COMPLETED      110
# 350  COMPLETED       59
# 351  COMPLETED       36
# 352  COMPLETED       25
# 353  COMPLETED      110
# 354  COMPLETED       33
# 355  COMPLETED       81
#
# [310 rows x 6 columns]

# %% [markdown]
# What are the webtoons updated on Monday? How many of them have a score below the average score of all webtoons? What are they?

# %%
# To query webtoons updated on Monday
monday = df[df.Status == everyday[0]]
monday.head()
# Out:
#                       Name  Heart  Score          Genre  Status  Episode
# 0                    Edith   1.5M   9.77        Romance  MONDAY       25
# 1                  SubZero   2.3M   9.82        Romance  MONDAY       28
# 2     Cursed Princess Club   1.2M   9.74         Comedy  MONDAY       25
# 3               Sweet Home   5.8M   9.84       Thriller  MONDAY       82
# 4  My Giant Nerd Boyfriend  20.7M   9.73  Slice of life  MONDAY      327

# %%
avg_score = df['Score'].mean()
avg_score
# Out:
# 9.34351612903226

# %%
# To query those with a score lower than average
below_avg = monday[monday['Score'] < avg_score]
below_avg
# Out:
#          Name    Heart  Score    Genre  Status  Episode
# 23  Messenger  376,973   9.18  Fantasy  MONDAY       53

# %% [markdown]
# Sorting the dataset by Heart

# %%
# Change the column from a string to a float
def value_to_float(x):
    if "M" in x:
        return float(x.replace('M',''))*1000000
    if "," in x:
        return float(x.replace(',',''))
    
# Apply value_to_float function to the Heart column
df['Heart'] = df['Heart'].map(value_to_float)

# %%
# Sorting the table by Heart
sort_by_heart = df.sort_values('Heart', ascending = False)
sort_by_heart[:10] # Top ten webtoons with the most Hearts
# Out:
#                         Name       Heart  Score          Genre     Status  \
# 4    My Giant Nerd Boyfriend  20700000.0   9.73  Slice of life     MONDAY
# 62                 Bluechair  19600000.0   9.73         Comedy  WEDNESDAY
# 86                unOrdinary  16800000.0   9.83        Fantasy   THURSDAY
# 174                  Lookism  15800000.0   9.83          Drama     SUNDAY
# 30               Winter Moon  14100000.0   9.44        Fantasy    TUESDAY
# 137               I Love Yoo  13500000.0   9.83        Romance     FRIDAY
# 6               Tower of God  13200000.0   9.83        Fantasy     MONDAY
# 29     Boyfriend of the Dead  13100000.0   9.78         Comedy    TUESDAY
# 140           Siren's Lament  11800000.0   9.76        Romance   SATURDAY
# 54                Let's Play  11100000.0   9.66        Romance    TUESDAY
#
#      Episode
# 4        327
# 62       692
# 86       151
# 174      239
# 30       270
# 137       96
# 6        435
# 29       200
# 140      157
# 54        80

# %%
sort_by_heart[-10:] # Last 10 webtoons with the least amount of Hearts
# Out:
#                 Name    Heart  Score          Genre     Status  Episode
# 77    Bloodless Wars  31343.0   9.25         Action  WEDNESDAY       10
# 338          War Cry  30343.0   7.18      Superhero  COMPLETED       26
# 221  The Brooklynite  23594.0   9.04      Superhero  COMPLETED       26
# 294    Just Ask Yuli  21004.0   7.56  Slice of life  COMPLETED       25
# 134         Acursian  18854.0   7.37        Fantasy     FRIDAY        9
# 136         FINALITY  15288.0   8.34       Thriller     FRIDAY        8
# 350    City of Walls  14042.0   7.44         Action  COMPLETED       59
# 263           Epic V  13603.0   5.67         Comedy  COMPLETED       27
# 81         STARCROSS   7955.0   7.56      Superhero  WEDNESDAY       17
# 225          Cyko-KO   5279.0   7.58         Comedy  COMPLETED       26

# %% [markdown]
# What are the webtoon with less than 100k hearts? Which genre are more likely to get less than 100k of hearts?

# %%
low_heart = sort_by_heart[sort_by_heart['Heart'] < 100000]
low_heart
# Out:
#                              Name    Heart  Score          Genre     Status  \
# 165              Metaphorical HER  96236.0   8.78          Drama   SATURDAY
# 206                        SHADOW  94956.0   9.41        Fantasy  COMPLETED
# 326                     Cyberbunk  94628.0   8.56         Sci-fi  COMPLETED
# 309                   Tickle Town  94207.0   6.60         Comedy  COMPLETED
# 130                 Brothers Bond  92098.0   9.25         Action     FRIDAY
# 91                   Brass & Sass  89524.0   9.53        Romance   THURSDAY
# 303                       Inarime  86667.0   8.82        Fantasy  COMPLETED
# 346               Cherry Blossoms  85695.0   9.20        Romance  COMPLETED
# 232                       Spirits  85400.0   9.06        Fantasy  COMPLETED
# 278             Midnight Rhapsody  85250.0   9.15  Slice of life  COMPLETED
# 38             Little Matcha Girl  84697.0   9.80        Fantasy    TUESDAY
# 101                    Simon Sues  83224.0   9.18       Thriller   THURSDAY
# 214                     Star Wars  81842.0   9.55         Sci-fi  COMPLETED
# 335                  Power Ballad  79541.0   9.08          Drama  COMPLETED
# 200                Unknown Caller  79369.0   9.53       Thriller  COMPLETED
# 354     Fantasy Sketch - The Game  74412.0   8.85        Fantasy  COMPLETED
# 247                    FAMILY MAN  74061.0   9.69          Drama  COMPLETED
# 272  Midnight Rhapsody : Season 2  73973.0   8.87  Slice of life  COMPLETED
# 351                Your Adventure  71522.0   9.08         Comedy  COMPLETED
# 224            Pacific Rim: Amara  68107.0   9.27         Sci-fi  COMPLETED
# 306                    Davinchibi  65233.0   8.85          Drama  COMPLETED
# 304                     Polidiocy  64715.0   7.28         Comedy  COMPLETED
# 323                          1000  64636.0   9.09         Action  COMPLETED
# 147                   Random Chat  62953.0   9.55          Drama   SATURDAY
# 295              All That You Are  61553.0   9.22          Drama  COMPLETED
# 316                        Caster  61351.0   9.02         Action  COMPLETED
# 126                    Thornstone  61322.0   9.09        Fantasy     FRIDAY
# 314                   Eat Fighter  54066.0   5.56         Comedy  COMPLETED
# 47                        Luggage  53695.0   8.61        Fantasy    TUESDAY
# 242                     The Cliff  43350.0   9.26       Thriller  COMPLETED
# 288            2015: Space Series  42789.0   9.26         Sci-fi  COMPLETED
# 204              New Life Project  41630.0   8.37         Comedy  COMPLETED
# 312                Shadow Pirates  41456.0   9.27        Fantasy  COMPLETED
# 191                  Varsity Noir  39777.0   9.04          Drama     SUNDAY
# 203                    Cyberforce  37591.0   7.88      Superhero  COMPLETED
# 287   The Life of the Three Bears  36855.0   8.90  Slice of life  COMPLETED
# 208                 Jingle Jungle  35581.0   8.87  Slice of life  COMPLETED
# 284                  The Red Hook  34406.0   8.26      Superhero  COMPLETED
# 328              The Purple Heart  34100.0   9.09      Superhero  COMPLETED
# 77                 Bloodless Wars  31343.0   9.25         Action  WEDNESDAY
# 338                       War Cry  30343.0   7.18      Superhero  COMPLETED
# 221               The Brooklynite  23594.0   9.04      Superhero  COMPLETED
# 294                 Just Ask Yuli  21004.0   7.56  Slice of life  COMPLETED
# 134                      Acursian  18854.0   7.37        Fantasy     FRIDAY
# 136                      FINALITY  15288.0   8.34       Thriller     FRIDAY
# 350                 City of Walls  14042.0   7.44         Action  COMPLETED
# 263                        Epic V  13603.0   5.67         Comedy  COMPLETED
# 81                      STARCROSS   7955.0   7.56      Superhero  WEDNESDAY
# 225                       Cyko-KO   5279.0   7.58         Comedy  COMPLETED
#
#      Episode
# 165       32
# 206       12
# 326      194
# 309      180
# 130       39
# 91         5
# 303       71
# 346        7
# 232       35
# 278       38
# 38         5
# 101       10
# 214       40
# 335       26
# 200        3
# 354       33
# 247       42
# 272       81
# 351       36
# 224       10
# 306        8
# 304       96
# 323       20
# 147        3
# 295       63
# 316       30
# 126       14
# 314       26
# 47         9
# 242        9
# 288       14
# 204       53
# 312       17
# 191       14
# 203       92
# 287       51
# 208      101
# 284       27
# 328       26
# 77        10
# 338       26
# 221       26
# 294       25
# 134        9
# 136        8
# 350       59
# 263       27
# 81        17
# 225       26

# %%
genres = df['Genre'].unique() # genres of webtoon
count_g = df['Genre'].nunique() # total number of genres
print("There are " + str(count_g) + ' genres of webtoons:')
print(genres)
# Out:
# There are 12 genres of webtoons:
# ['Romance' 'Comedy' 'Thriller' 'Slice of life' 'Fantasy' 'Action' 'Drama'
#  'Sci-fi' 'Sports' 'Superhero' 'Informative' 'Horror']

# %%
heart_genre = low_heart['Genre'].value_counts()
heart_genre
# Out:
# Fantasy          9
# Comedy           7
# Drama            7
# Superhero        6
# Action           5
# Slice of life    5
# Thriller         4
# Sci-fi           4
# Romance          2
# Name: Genre, dtype: int64

# %% [markdown]
# The genre Fantasy is the most likely to get less than 100k hearts.

# %% [markdown]
# ## Using SQL
