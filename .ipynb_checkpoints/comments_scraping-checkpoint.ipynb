# %%
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup
import csv
import numpy as np
import pandas as pd

# %% [markdown]
# $Sweet Home$

# %%
quote_page = 'https://www.webtoons.com/en/dailySchedule'

# query the website and return the html to the variable ‘page’
page = urlopen(quote_page)
soup = BeautifulSoup(page, 'html.parser')

everyday = np.array(["MONDAY","TUESDAY","WEDNESDAY","THURSDAY","FRIDAY","SATURDAY","SUNDAY","COMPLETED"])
for i in range(len(everyday)):
    if everyday[i] == "COMPLETED":
        update_find = "daily_lst comp"
    else: 
        update_find = "daily_section _list_" + everyday[i]
    d_day = soup.find(class_= update_find)
    name = d_day.find_all('p', class_ = 'subj')
    likes = d_day.find_all('em')
    score = d_day.find_all()
    genre = d_day.find_all('p', class_ = 'genre')
    print(everyday[i], d_day)
# Out:
# MONDAY <div class="daily_section _list_MONDAY">
# <h2><a class="_weekdaySelect NPI=a:mon,g:en_en" data-weekday="MONDAY" href="#">MON</a></h2>
# <ul class="daily_card">
# <li>
# <a class="daily_card_item NPI=a:list,i=1468,r=1,g:en_en" href="https://www.webtoons.com/en/romance/subzero/list?title_no=1468">
# <img alt="" height="138" src="https://webtoon-phinf.pstatic.net/20181022_300/1540173096133NHuNf_JPEG/10_EC8DB8EB84A4EC9DBC_ipad.jpg?type=a138" width="138"/>
# <p class="genre g_romance">Romance</p>
# <div class="info">
# <p class="subj">SubZero</p>
# <p class="author">Junepurrr</p>
# <p class="icon_area"></p>
# </div>
# <p class="grade_area"><span class="ico_like3">like</span><em class="grade_num">2.5M</em></p>
# </a>
# </li>
# <li>
# <a class="daily_card_item NPI=a:list,i=1537,r=2,g:en_en" href="https://www.webtoons.com/en/comedy/cursed-princess-club/list?title_no=1537">
# ...

# %%
page = requests.get('https://www.webtoons.com/en/thriller/sweethome/ep-83/viewer?title_no=1285&episode_no=84')
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the BodyText div
base = soup.find(class_ = 'cont_box', id = '_bottomDisplay')
base2 = soup.find_all(class_ = 'comment_area')
#user = base.find_all(class_= 'u_cbox_nick')
# comment = base.find_all('span', class_='u_cbox_contents')

# wt_comments = csv.writer(open('wt_comments.csv', 'w')) # Created csv file
# wt_comments.writerow(['Name', 'Link'])

# for u,c in zip(user, comment):
#     users = user.contents[0]
#     comments = comment.contents[0]
#     wt_comments.writerow([user, comments])

# %%
base2
# Out:
# [<div class="comment_area">
#  <div id="cbox_module"></div>
#  </div>]

# %%
base
# Out:
# <div class="cont_box" id="_bottomDisplay">
# <div class="comment_area">
# <div id="cbox_module"></div>
# </div>
# <div class="aside viewer">
# <div class="ranking_lst viewer">
# <div class="lst_area NE=a:vgt" id="genreRanking">
# <div class="title_area">
# <h2><a class="_rankingMoveBtn NPI=a:more,g:en_en" href="#">By Genre</a> <em class="ico_arr1">&gt;</em></h2>
# <div class="sort_area _filterArea">
# <a class="checked" href="#">Others <span class="ico_chk">(selected)</span></a>
# <ul class="sort_box _filterLayer">
# <li><a class="_filterItem NPI=a:byall,g:en_en" data-filter="ALL" href="#">ALL</a></li>
# <li><a class="_filterItem NPI=a:byact,g:en_en" data-filter="ACTION_FANTASY" href="#">Action/Fantasy</a></li>
# <li><a class="_filterItem NPI=a:byrom,g:en_en" data-filter="ROMANCE_DRAMA" href="#">Romance/Drama</a></li>
# <li><a class="_filterItem NPI=a:bycom,g:en_en" data-filter="COMEDY" href="#">Comedy</a></li>
# ...

# %%
print(base)
# Out:
# <div class="cont_box" id="_bottomDisplay">
# <div class="comment_area">
# <div id="cbox_module"></div>
# </div>
# <div class="aside viewer">
# <div class="ranking_lst viewer">
# <div class="lst_area NE=a:vgt" id="genreRanking">
# <div class="title_area">
# <h2><a class="_rankingMoveBtn NPI=a:more,g:en_en" href="#">By Genre</a> <em class="ico_arr1">&gt;</em></h2>
# <div class="sort_area _filterArea">
# <a class="checked" href="#">ALL <span class="ico_chk">(selected)</span></a>
# <ul class="sort_box _filterLayer">
# <li><a class="_filterItem NPI=a:byall,g:en_en" data-filter="ALL" href="#">ALL <span class="ico_chk">(selected)</span></a></li>
# <li><a class="_filterItem NPI=a:byact,g:en_en" data-filter="ACTION_FANTASY" href="#">Action/Fantasy</a></li>
# <li><a class="_filterItem NPI=a:byrom,g:en_en" data-filter="ROMANCE_DRAMA" href="#">Romance/Drama</a></li>
# <li><a class="_filterItem NPI=a:bycom,g:en_en" data-filter="COMEDY" href="#">Comedy</a></li>
# ...

# %%
soup.find('ul',class_="u_cbox_list")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-d5c4164ef5b5> in <module>
# ----> 1 soup.find('ul',class_="u_cbox_list").prettify()
#
# AttributeError: 'NoneType' object has no attribute 'prettify'
