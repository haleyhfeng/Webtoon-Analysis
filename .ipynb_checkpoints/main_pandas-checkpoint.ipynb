# %%
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup
import csv
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data Scraping

# %%
def get_rating(link):
    page = urlopen(link)
    soup = BeautifulSoup(page, 'html.parser')
    score = soup.find("em", class_='cnt')
    return score.contents[0]

# %%
def get_chapter(link):
    page = urlopen(link)
    soup = BeautifulSoup(page, 'html.parser')
    chapter = soup.find("span", class_='tx')
    chapter = chapter.contents[0]
    return int(chapter.replace("#",''))

# %%
quote_page = 'https://www.webtoons.com/en/dailySchedule'

# query the website and return the html to the variable ‘page’
page = urlopen(quote_page)
soup = BeautifulSoup(page, 'html.parser')

# create csv
webtoon_data = csv.writer(open('webtoons_data.csv', 'w'))
webtoon_data.writerow(['Name', 'Heart', 'Score', 'Genre', 'Status', "Episode"])


everyday = np.array(["MONDAY","TUESDAY","WEDNESDAY","THURSDAY","FRIDAY","SATURDAY","SUNDAY","COMPLETED"])
for i in range(len(everyday)):
    if everyday[i] == "COMPLETED":
        update_find = "daily_lst comp"
    else: 
        update_find = "daily_section _list_" + everyday[i]
    d_day = soup.find(class_= update_find)
    name = d_day.find_all('p', class_ = 'subj')
    likes = d_day.find_all('em')
    score = d_day.find_all()
    genre = d_day.find_all('p', class_ = 'genre')
    webtoon_link = []
    for link in d_day.find_all('a'):
        if link.get('href') == "#":
            continue
        else:
            webtoon_link.append(link.get('href'))
    for n,l,g,s in zip(name, likes, genre, range(len(webtoon_link))):
        N = n.contents[0]
        L = l.contents[0]
        G = g.contents[0]
        scores = get_rating(webtoon_link[s])
        chapters = get_chapter(webtoon_link[s])
        webtoon_data.writerow([N,L,scores,G,everyday[i],chapters])

# %% [markdown]
# ## Using pandas

# %%
df = pd.read_csv('webtoons_data.csv')
df.loc[df['Name'] == "Yumi's Cells"]
# Out:
#              Name Heart  Score    Genre     Status  Episode
# 69   Yumi's Cells  7.2M   9.74  Romance  WEDNESDAY      392
# 154  Yumi's Cells  7.2M   9.74  Romance   SATURDAY      392

# %%
len(df)
# Out:
# 340

# %%
df
# Out:
#                                         Name    Heart  Score          Genre  \
# 0                                    SubZero     2.4M   9.82        Romance
# 1                                      Edith     1.6M   9.76        Romance
# 2                       Cursed Princess Club     1.3M   9.74         Comedy
# 3                                 Sweet Home     5.9M   9.84       Thriller
# 4                    My Giant Nerd Boyfriend    20.9M   9.73  Slice of life
# 5                                 Ghost Wife       4M   9.67        Romance
# 6                                  Code Adam  183,377   9.83         Action
# 7    Love Advice from the Great Duke of Hell     3.6M   9.78         Comedy
# 8                               Tower of God    13.3M   9.83        Fantasy
# 9                           The Four of Them  865,630   9.60          Drama
# 10                            Room of Swords     1.8M   9.78         Sci-fi
# 11                           Matchmaker Hero  503,959   9.67         Sci-fi
# 12                                    Big Jo     3.3M   9.54          Drama
# 13                         Safely Endangered     9.6M   9.54         Comedy
# 14                                DON'T HATE  729,936   9.43         Comedy
# 15                               Heir's Game  829,375   9.66          Drama
# 16                              As Per Usual     5.5M   9.40         Comedy
# 17                              Wind Breaker     2.7M   9.84         Action
# 18                           dustinteractive     4.7M   9.37         Comedy
# 19                              Aerial Magic       1M   9.70          Drama
# 20                           A Budgie's Life     5.3M   9.78  Slice of life
# 21                                      Plum  135,403   9.55         Sports
# 22                       Cat Loaf Adventures     1.3M   9.56  Slice of life
# 23                                 Messenger  383,271   9.17        Fantasy
# 24                               Lunarbaboon     2.8M   9.65  Slice of life
# 25                                    Kubera     1.8M   9.71        Fantasy
# 26                                   EMPYREA     1.2M   9.79        Fantasy
# 27                                      LUFF     2.2M   9.56        Romance
# 28                         My Deepest Secret  890,319   9.70          Drama
# 29                     Boyfriend of the Dead    13.2M   9.78         Comedy
# ..                                       ...      ...    ...            ...
# 310                                MercWorks  379,117   9.12         Comedy
# 311                             Aphrodite IX  119,024   8.74         Sci-fi
# 312                              Tickle Town   94,340   6.61         Comedy
# 313          The Strange Tales of Oscar Zahn  782,415   9.76        Fantasy
# 314                       Have You Any Fear?  119,262   8.54         Horror
# 315                           Shadow Pirates   41,517   9.27        Fantasy
# 316                          Under the Aegis  382,253   9.74        Fantasy
# 317                              Eat Fighter   54,130   5.56         Comedy
# 318                             1111 Animals  204,132   8.89         Comedy
# 319                                   Caster   61,486   9.02         Action
# 320                     My Kitty and Old Dog  712,942   9.64  Slice of life
# 321                                  Hellper  413,079   9.73         Action
# 322                                Nano List     2.3M   9.82         Sci-fi
# 323                              The Badguys  211,949   9.44      Superhero
# 324                                    Shard  700,841   9.30          Drama
# 325                                     CARL       3M   9.76         Comedy
# 326                                     1000   64,819   9.09         Action
# 327                              Alice Elise  115,564   9.02        Fantasy
# 328            Ghosts Among the Wild Flowers  338,017   9.56        Fantasy
# 329                                Cyberbunk   95,110   8.56         Sci-fi
# 330                             The Red Book  167,197   8.79       Thriller
# 331                         The Purple Heart   34,197   9.09      Superhero
# 332                                 UndeadEd  637,175   9.68         Comedy
# 333                 The Gentleman’s Armchair  245,758   8.90         Comedy
# 334                   All That We Hope to Be  126,165   9.46  Slice of life
# 335                                MOONBEARD  353,365   9.26         Comedy
# 336                              How to Love  492,709   9.49  Slice of life
# 337                               Trash Bird  923,013   9.53         Comedy
# 338                             Power Ballad   79,887   9.08          Drama
# 339                            Library Ghost  195,815   8.77  Slice of life
#
#         Status  Episode
# 0       MONDAY       29
# 1       MONDAY       26
# 2       MONDAY       26
# 3       MONDAY       83
# 4       MONDAY      329
# 5       MONDAY       80
# 6       MONDAY        7
# 7       MONDAY       61
# 8       MONDAY      436
# 9       MONDAY       27
# 10      MONDAY       76
# 11      MONDAY       16
# 12      MONDAY      120
# 13      MONDAY      487
# 14      MONDAY       37
# 15      MONDAY       45
# 16      MONDAY      361
# 17      MONDAY      239
# 18      MONDAY      406
# 19      MONDAY       50
# 20      MONDAY      350
# 21      MONDAY       17
# 22      MONDAY      130
# 23      MONDAY       54
# 24      MONDAY      558
# 25      MONDAY      401
# 26      MONDAY       27
# 27     TUESDAY       31
# 28     TUESDAY       16
# 29     TUESDAY      202
# ..         ...      ...
# 310  COMPLETED      150
# 311  COMPLETED       33
# 312  COMPLETED      180
# 313  COMPLETED      105
# 314  COMPLETED       10
# 315  COMPLETED       17
# 316  COMPLETED       93
# 317  COMPLETED       26
# 318  COMPLETED      110
# 319  COMPLETED       30
# 320  COMPLETED      213
# 321  COMPLETED      189
# 322  COMPLETED      147
# 323  COMPLETED       73
# 324  COMPLETED       80
# 325  COMPLETED      150
# 326  COMPLETED       20
# 327  COMPLETED       24
# 328  COMPLETED       87
# 329  COMPLETED      194
# 330  COMPLETED       26
# 331  COMPLETED       26
# 332  COMPLETED      120
# 333  COMPLETED      142
# 334  COMPLETED      176
# 335  COMPLETED      147
# 336  COMPLETED      100
# 337  COMPLETED      174
# 338  COMPLETED       26
# 339  COMPLETED       75
#
# [340 rows x 6 columns]

# %%
#Delete repeated webtoons since some of them update more than once a week
df.drop_duplicates(subset = "Name", inplace = True)
df.to_csv('webtoons_data.csv', index = False) 

# Saving updated csv file
df = pd.read_csv('webtoons_data.csv')

# %% [markdown]
# #### What are the webtoons updated on Monday? How many of them have a score below the average score of all webtoons? What are they?

# %%
# To query webtoons updated on Monday
everyday = np.array(["MONDAY","TUESDAY","WEDNESDAY","THURSDAY","FRIDAY","SATURDAY","SUNDAY","COMPLETED"])
monday = df[df.Status == everyday[0]]
monday.head()
# Out:
#                       Name  Heart  Score          Genre  Status  Episode
# 0                  SubZero   2.4M   9.82        Romance  MONDAY       29
# 1                    Edith   1.6M   9.76        Romance  MONDAY       26
# 2     Cursed Princess Club   1.3M   9.74         Comedy  MONDAY       26
# 3               Sweet Home   5.9M   9.84       Thriller  MONDAY       83
# 4  My Giant Nerd Boyfriend  20.9M   9.73  Slice of life  MONDAY      329

# %%
avg_score = df['Score'].mean()
avg_score
# Out:
# 9.357269624573377

# %%
# To query those with a score lower than average
below_avg = monday[monday['Score'] < avg_score]
below_avg
# Out:
#          Name    Heart  Score    Genre  Status  Episode
# 23  Messenger  383,271   9.17  Fantasy  MONDAY       54

# %% [markdown]
# Sorting the dataset by Heart

# %%
# Change the column from a string to a float
def value_to_float(x):
    if "M" in x:
        return float(x.replace('M',''))*1000000
    if "," in x:
        return float(x.replace(',',''))
    
# Apply value_to_float function to the Heart column
df['Heart'] = df['Heart'].map(value_to_float)

# %%
# Sorting the table by Heart
sort_by_heart = df.sort_values('Heart', ascending = False)
sort_by_heart[:10] # Top ten webtoons with the most Hearts
# Out:
#                         Name       Heart  Score          Genre     Status  \
# 4    My Giant Nerd Boyfriend  20900000.0   9.73  Slice of life     MONDAY
# 61                 Bluechair  19700000.0   9.73         Comedy  WEDNESDAY
# 82                unOrdinary  17100000.0   9.83        Fantasy   THURSDAY
# 140                  Lookism  15900000.0   9.83          Drama     SUNDAY
# 30               Winter Moon  14300000.0   9.44        Fantasy    TUESDAY
# 114               I Love Yoo  13600000.0   9.83        Romance     FRIDAY
# 8               Tower of God  13300000.0   9.83        Fantasy     MONDAY
# 29     Boyfriend of the Dead  13200000.0   9.78         Comedy    TUESDAY
# 116           Siren's Lament  11900000.0   9.76        Romance   SATURDAY
# 54                Let's Play  11100000.0   9.66        Romance    TUESDAY
#
#      Episode
# 4        329
# 61       694
# 82       152
# 140      240
# 30       273
# 114       96
# 8        436
# 29       202
# 116      158
# 54        80

# %%
sort_by_heart[-10:] # Last 10 webtoons with the least amount of Hearts
# Out:
#                   Name    Heart  Score          Genre     Status  Episode
# 284   The Purple Heart  34197.0   9.09      Superhero  COMPLETED       26
# 74      Bloodless Wars  32321.0   9.24         Action  WEDNESDAY       10
# 177    The Brooklynite  23644.0   9.04      Superhero  COMPLETED       26
# 250      Just Ask Yuli  21067.0   7.56  Slice of life  COMPLETED       25
# 111           Acursian  18896.0   7.36        Fantasy     FRIDAY        9
# 126  Skate!!! Fire 100  17035.0   9.43        Fantasy   SATURDAY        3
# 113           FINALITY  15327.0   8.34       Thriller     FRIDAY        8
# 219             Epic V  13616.0   5.66         Comedy  COMPLETED       27
# 77           STARCROSS   8170.0   7.54      Superhero  WEDNESDAY       17
# 181            Cyko-KO   5340.0   7.56         Comedy  COMPLETED       26

# %% [markdown]
# #### What are the webtoon with less than 100k hearts? Which genre are more likely to get less than 100k of hearts?

# %%
low_heart = sort_by_heart[sort_by_heart['Heart'] < 100000]
low_heart.head()
# Out:
#                  Name    Heart  Score    Genre     Status  Episode
# 132  Metaphorical HER  96584.0   8.78    Drama   SATURDAY       32
# 162            SHADOW  95367.0   9.41  Fantasy  COMPLETED       12
# 282         Cyberbunk  95110.0   8.56   Sci-fi  COMPLETED      194
# 265       Tickle Town  94340.0   6.61   Comedy  COMPLETED      180
# 109     Brothers Bond  93901.0   9.26   Action     FRIDAY       40

# %%
genres = df['Genre'].unique() # genres of webtoon
count_g = df['Genre'].nunique() # total number of genres
print("There are " + str(count_g) + ' genres of webtoons:')
print(genres)
# Out:
# There are 12 genres of webtoons:
# ['Romance' 'Comedy' 'Thriller' 'Slice of life' 'Action' 'Fantasy' 'Drama'
#  'Sci-fi' 'Sports' 'Superhero' 'Informative' 'Horror']

# %%
heart_genre = low_heart['Genre'].value_counts()
heart_genre
# Out:
# Fantasy          8
# Comedy           7
# Drama            7
# Slice of life    5
# Superhero        5
# Action           4
# Sci-fi           4
# Thriller         4
# Name: Genre, dtype: int64

# %% [markdown]
# The genre Fantasy is the most likely to get less than 100k hearts.
